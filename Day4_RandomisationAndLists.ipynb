# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/Python_100DaysofCode/blob/main/Day4_RandomisationAndLists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Module

# %%
import random
c = random.randint(10,20)
print(c)
# Out:
# 17

# %%
# Random floating point number
c = random.random() # between to 0 to 1 only
print(c)
# Out:
# 0.0843721426819306

# %%
  # Random float number between 0 and 5
  b = random.randint(0,5)
  a = random.random()
  c= a*b
  print(c)
# Out:
# 2.028624457418053

# %% [markdown]
# # Heads or Tails

# %%
import random	 
	 
h_t= random.randint(0,1)
if h_t==1:
    print('Heads')
else:
    print('Tails')
# Out:
# Heads

# %% [markdown]
# # Lists

# %%
fruits = ['apple','mango', 'cherry', 'orange']

# %%
# access items in the list
fruits[0]
# Out:
# 'apple'

# %%
# access by negative index
fruits[-1]
# Out:
# 'orange'

# %%
# update list
fruits[3] = 'Oranges'
print(fruits  )
# Out:
# ['apple', 'mango', 'cherry', 'Oranges']

# %%
# appended at the end
fruits.append('banana')
print(fruits)
# Out:
# ['apple', 'mango', 'cherry', 'Oranges', 'banana']

# %% [markdown]
# # Banking Roulette Game

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random
# 🚨 Don't change the code below 👇
test_seed = int(input("Create a seed number: "))
random.seed(test_seed)

# Split string method
names_string = input("Give me everybody's names, separated by a comma. ")
names = names_string.split(",")
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
c = random.randint(0,len(names)-1)
print(f"{names[c]} is going to buy the meal today!")
# Out:
# Create a seed number: 123
# Give me everybody's names, separated by a comma. Aftab,Anil,Amar
# Aftab is going to buy the meal today!

# %% [markdown]
# # Treasure map

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# First, your program must take the user input and convert it to a usable format.
#
# Next, you need to use it to update your nested list with an "x".

# %%
# 🚨 Don't change the code below 👇
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure? ")
# 🚨 Don't change the code above 👆

#Write your code below this row 👇
col_pos = int(position[0])-1
row_pos = int(position[1])-1
map[row_pos][col_pos]='X'

#Write your code above this row 👆

# 🚨 Don't change the code below 👇
print(f"{row1}\n{row2}\n{row3}")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# Where do you want to put the treasure? 32
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', 'X']
# ['⬜️', '⬜️', '⬜️']

# %% [markdown]
# # Rock Paper Scissors Game

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

#Write your code below this line 👇
listofRPS = [rock,paper,scissors]
user_inp= int(input('What do you want to choose? Type 0 for Rock, 1 for Paper, 2 for Scissors'))
print(listofRPS[user_inp])
import random
comp_inp= random.randint(0,2)

print(listofRPS[comp_inp])
if user_inp==0:
  if comp_inp==1:
    print("You loose")
  elif comp_inp==2:
    print('You win')
  else:
    print('Its a draw')
elif user_inp==1:
  if comp_inp==1:
      print("Its a draw")
  elif comp_inp==2:
    print('You loose')
  else:
    print('You win')
elif user_inp==2:
  if comp_inp==0:
    print("You loose")
  elif comp_inp==1:
    print('You win')
  else:
    print('Its a draw')
# Out:
# What do you want to choose? Type 0 for Rock, 1 for Paper, 2 for Scissors2
#
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
#
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# Its a draw
