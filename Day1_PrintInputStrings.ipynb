# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/Python_100DaysofCode/blob/main/Day1_PrintInputStrings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Printing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Day 1 - Python Print Function\nThe function is declared like this:\nprint(\'what to print\')")
# Out:
# Day 1 - Python Print Function
# The function is declared like this:
# print('what to print')

# %% [markdown]
# # Debugging

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Fix the code below 👇

print("Day 1 - String Manipulation")
print('String Concatenation is done with the "+" sign.')
print('e.g. print("Hello " + "world")')
print("New lines can be created with a backslash and n.")
# Out:
# Day 1 - String Manipulation
# String Concatenation is done with the "+" sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash and n.

# %% [markdown]
# # Input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s=input('What is your name?')
print(len(s))
# Out:
# What is your name?Aftab
# 5

# %%
#making single line of code
print(len(input('What is your name?')))
# Out:
# What is your name?Aftab
# 5

# %% [markdown]
# # Variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 🚨 Don't change the code below 👇
a = input("a: ")
b = input("b: ")
# 🚨 Don't change the code above 👆

####################################
#Write your code below this line 👇
c = a
a = b
b = c



#Write your code above this line 👆
####################################

# 🚨 Don't change the code below 👇
print("a: " + a)
print("b: " + b)
# Out:
# a: 12
# b: 13
# a: 13
# b: 12

# %% [markdown]
# # Band Name Generator

# %%
print('Hi Welcome to the Band Name Generator')
city = input('What city are you grew up in ? ')
pet = input('What is name of your pet ? ')
print('You can name your band as %s %s'%(city,pet))
# Out:
# What city are you from ? Mumbai
# What is name of your pet ? Champ
# You can name your band as Mumbai Champ
